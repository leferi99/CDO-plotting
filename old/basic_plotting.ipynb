# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.constrained_layout.use'] = True

a = 2.93
r = np.linspace(0, a, 55)
x = r / a
j = (5.86/((1.256637062e-6)*9.07))*(3.5 + (2.61853)*x + (-124.87584)*x**2 + (617.12337)*x**3 + (-1407.63322)*x**4 + (1729.75352)*x**5 + (-1208.85202)*x**6 + (485.97806)*x**7 + (-97.60636)*x**8)

plot = plt.figure(figsize=[5.5, 4])
plt.plot(r, j, linewidth=3)
ax = plt.gca()
ax.set_ylabel(r"Current density [A/m$^2$]", fontweight='bold')
ax.set_xlabel("Minor radius [m]", fontweight='bold')
ax.set_ylim(0, None)
ax.set_xlim(0, None)
# Out:
# (0.0, 3.0765000000000002)
